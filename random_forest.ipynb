# %%
import pandas as pd
import string
import re
import numpy as np

# %%
# !pip install imblearn
from imblearn.over_sampling import RandomOverSampler
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.8.1-py3-none-any.whl (189 kB)
#      |████████████████████████████████| 189 kB 3.4 MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn>=0.24 in /Users/skadiyala/.local/share/virtualenvs/nlp-tSIpt5ka/lib/python3.7/site-packages (from imbalanced-learn->imblearn) (1.0)
# Requirement already satisfied: scipy>=0.19.1 in /Users/skadiyala/.local/share/virtualenvs/nlp-tSIpt5ka/lib/python3.7/site-packages (from imbalanced-learn->imblearn) (1.7.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/skadiyala/.local/share/virtualenvs/nlp-tSIpt5ka/lib/python3.7/site-packages (from imbalanced-learn->imblearn) (1.21.2)
# Requirement already satisfied: joblib>=0.11 in /Users/skadiyala/.local/share/virtualenvs/nlp-tSIpt5ka/lib/python3.7/site-packages (from imbalanced-learn->imblearn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/skadiyala/.local/share/virtualenvs/nlp-tSIpt5ka/lib/python3.7/site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn) (3.0.0)
# Installing collected packages: imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.8.1 imblearn-0.0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.models import Word2Vec
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
questions = pd.read_csv("./data/labelled_clean_questions.csv")

# %%
text = questions["clean_tokenized"]
target = questions["target"].values

X_train, X_test, y_train, y_test = train_test_split(text, target, stratify=target, test_size=0.25)

# %%
X_train = X_train.values.astype('U')
X_test = X_test.values.astype('U')

# %% [markdown]
# TF-IDF + Random Forest Model + Oversampling

# %%
over_sampler = RandomOverSampler(random_state=42)
X_res, y_res = over_sampler.fit_resample(X_train.reshape(-1,1), y_train.reshape(-1,1))

# %%
from collections import Counter
print(f"Training target statistics: {Counter(y_res)}")
print(f"Testing target statistics: {Counter(y_test)}")
# Out:
# Training target statistics: Counter({0: 918984, 1: 918984})
# Testing target statistics: Counter({0: 306328, 1: 20203})

# %%
X_res = np.array(X_res).flatten()

# %%
vectorizer = TfidfVectorizer(use_idf=True, ngram_range=(1,2))
tfidf_model = vectorizer.fit(X_res)
train_tfidf = tfidf_model.transform(X_res)
test_tfidf = tfidf_model.transform(X_test)

# %%
clf = RandomForestClassifier(max_depth= 20, min_samples_leaf= 3, min_samples_split= 3, n_estimators= 1200)
clf.fit(train_tfidf, y_res)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_leaf=3, min_samples_split=3,
#                        n_estimators=1200)

# %%
preds = clf.predict(test_tfidf)
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93    306328
#            1       0.29      0.77      0.42     20203
#
#     accuracy                           0.87    326531
#    macro avg       0.64      0.82      0.67    326531
# weighted avg       0.94      0.87      0.90    326531

# %%
train_balanced["target"].value_counts()
# Out:
# 1    80810
# 0    80810
# Name: target, dtype: int64

# %% [markdown]
# TF-IDF + UNDERSAMPLED + RANDOM FOREST

# %%
train_balanced = questions[questions['target'] == 1]
train_balanced = train_balanced.append(questions[questions['target'] == 0].sample(n = len(train_balanced))).reset_index(drop = True)
train_balanced['target'].value_counts()

balanced_text = train_balanced["clean_tokenized"].values.astype('U')

train_text, test_text, target_train, target_test = train_test_split(balanced_text, train_balanced["target"], stratify=train_balanced["target"], test_size=0.25)

# %%
vectorizer = TfidfVectorizer(use_idf=True, ngram_range=(1,2))
tfidf_model = vectorizer.fit(train_text)
train_tfidf = tfidf_model.transform(train_text)
test_tfidf = tfidf_model.transform(test_text)

# %%
clf = RandomForestClassifier(max_depth= 20, min_samples_leaf= 3,
                         min_samples_split= 3, n_estimators= 1200)
clf.fit(train_tfidf, target_train)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_leaf=3, min_samples_split=3,
#                        n_estimators=1200)

# %%
preds = clf.predict(test_tfidf)
print(classification_report(target_test, preds))

# %%
print(classification_report(target_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83     20203
#            1       0.86      0.77      0.81     20202
#
#     accuracy                           0.82     40405
#    macro avg       0.82      0.82      0.82     40405
# weighted avg       0.82      0.82      0.82     40405

# %%
clf = RandomForestClassifier(max_depth= 20, min_samples_leaf= 3,
                         min_samples_split= 3, n_estimators= 1000)
clf.fit(train_tfidf, target_train)

preds = clf.predict(test_tfidf)
print(classification_report(target_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.83     20203
#            1       0.85      0.77      0.81     20202
#
#     accuracy                           0.82     40405
#    macro avg       0.82      0.82      0.82     40405
# weighted avg       0.82      0.82      0.82     40405

# %%
clf = RandomForestClassifier(max_depth= 20, min_samples_leaf= 3,
                         min_samples_split= 3, n_estimators= 1000, max_features="log2")
clf.fit(train_tfidf, target_train)

preds = clf.predict(test_tfidf)
print(classification_report(target_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.87      0.79     20203
#            1       0.84      0.68      0.75     20202
#
#     accuracy                           0.77     40405
#    macro avg       0.78      0.77      0.77     40405
# weighted avg       0.78      0.77      0.77     40405

# %%
clf = RandomForestClassifier(max_depth= 20, min_samples_leaf= 3,
                         min_samples_split= 3, n_estimators= 1000, max_features="sqrt")
clf.fit(train_tfidf, target_train)

preds = clf.predict(test_tfidf)
print(classification_report(target_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83     20203
#            1       0.86      0.77      0.81     20202
#
#     accuracy                           0.82     40405
#    macro avg       0.82      0.82      0.82     40405
# weighted avg       0.82      0.82      0.82     40405

# %%
clf = RandomForestClassifier(max_depth= 20, min_samples_leaf= 3,
                         min_samples_split= 3, n_estimators= 2000, max_features="sqrt")
clf.fit(train_tfidf, target_train)

preds = clf.predict(test_tfidf)
print(classification_report(target_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83     20203
#            1       0.85      0.77      0.81     20202
#
#     accuracy                           0.82     40405
#    macro avg       0.82      0.82      0.82     40405
# weighted avg       0.82      0.82      0.82     40405

# %%
clf = RandomForestClassifier(max_depth= 20, min_samples_leaf= 3,
                         min_samples_split= 3, n_estimators= 2000, max_features="auto")
clf.fit(train_tfidf, target_train)

preds = clf.predict(test_tfidf)
print(classification_report(target_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83     20203
#            1       0.85      0.77      0.81     20202
#
#     accuracy                           0.82     40405
#    macro avg       0.82      0.82      0.82     40405
# weighted avg       0.82      0.82      0.82     40405

# %%
clf = RandomForestClassifier(max_depth= 30, min_samples_leaf= 3,
                         min_samples_split= 3, n_estimators= 2000, max_features="auto")
clf.fit(train_tfidf, target_train)

preds = clf.predict(test_tfidf)
print(classification_report(target_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83     20203
#            1       0.85      0.78      0.81     20202
#
#     accuracy                           0.82     40405
#    macro avg       0.82      0.82      0.82     40405
# weighted avg       0.82      0.82      0.82     40405

# %%
clf = RandomForestClassifier(max_depth= 30, min_samples_leaf= 3,
                         min_samples_split= 5, n_estimators= 2000, max_features="auto")
clf.fit(train_tfidf, target_train)

preds = clf.predict(test_tfidf)
print(classification_report(target_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83     20203
#            1       0.85      0.78      0.81     20202
#
#     accuracy                           0.82     40405
#    macro avg       0.83      0.82      0.82     40405
# weighted avg       0.83      0.82      0.82     40405

# %%
clf = RandomForestClassifier(max_depth= 30, min_samples_leaf= 3,
                         min_samples_split= 5, n_estimators= 700, max_features="auto")
clf.fit(train_tfidf, target_train)

preds = clf.predict(test_tfidf)
print(classification_report(target_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83     20203
#            1       0.85      0.78      0.81     20202
#
#     accuracy                           0.82     40405
#    macro avg       0.82      0.82      0.82     40405
# weighted avg       0.82      0.82      0.82     40405

# %%
clf = RandomForestClassifier(max_depth= 30, min_samples_leaf= 3,
                         min_samples_split= 5, n_estimators= 7000, max_features="auto")
clf.fit(train_tfidf, target_train)

preds = clf.predict(test_tfidf)
print(classification_report(target_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83     20203
#            1       0.85      0.78      0.81     20202
#
#     accuracy                           0.82     40405
#    macro avg       0.83      0.82      0.82     40405
# weighted avg       0.83      0.82      0.82     40405

# %%
questions["question_text"]
# Out:
#                           qid  \
# 0        00002165364db923c7e6
# 1        000032939017120e6e44
# 2        0000412ca6e4628ce2cf
# 3        000042bf85aa498cd78e
# 4        0000455dfa3e01eae3af
# ...                       ...
# 1306117  ffffcc4e2331aaf1e41e
# 1306118  ffffd431801e5a2f4861
# 1306119  ffffd48fb36b63db010c
# 1306120  ffffec519fa37cf60c78
# 1306121  ffffed09fedb5088744a
#
#                                              question_text  target  \
# 0        How did Quebec nationalists see their province...       0
# 1        Do you have an adopted dog, how would you enco...       0
# 2        Why does velocity affect time? Does velocity a...       0
# 3        How did Otto von Guericke used the Magdeburg h...       0
# 4        Can I convert montra helicon D to a mountain b...       0
# ...                                                    ...     ...
# 1306117  What other technical skills do you need as a c...       0
# 1306118  Does MS in ECE have good job prospects in USA ...       0
# 1306119                          Is foam insulation toxic?       0
# 1306120  How can one start a research project based on ...       0
# 1306121  Who wins in a battle between a Wolverine and a...       0
#
#                                                  tokenized  length  \
# 0        ['How', 'did', 'Quebec', 'nationalists', 'see'...      14
# 1        ['Do', 'you', 'have', 'an', 'adopted', 'dog', ...      18
# 2        ['Why', 'does', 'velocity', 'affect', 'time', ...      12
# 3        ['How', 'did', 'Otto', 'von', 'Guericke', 'use...      10
# 4        ['Can', 'I', 'convert', 'montra', 'helicon', '...      16
# ...                                                    ...     ...
# 1306117  ['What', 'other', 'technical', 'skills', 'do',...      18
# 1306118  ['Does', 'MS', 'in', 'ECE', 'have', 'good', 'j...      20
# 1306119         ['Is', 'foam', 'insulation', 'toxic', '?']       5
# 1306120  ['How', 'can', 'one', 'start', 'a', 'research'...      14
# 1306121  ['Who', 'wins', 'in', 'a', 'battle', 'between'...      12
#
#                                            clean_tokenized
# 0        how did quebec nationalist see their provinc a...
# 1        do you have an adopt dog how would you encoura...
# 2        whi doe veloc affect time ? doe veloc affect s...
# 3        how did otto von guerick use the magdeburg hem...
# 4        can i convert montra helicon d to a mountain b...
# ...                                                    ...
# 1306117  what other technic skill do you need as a comp...
# 1306118  doe ms in ece have good job prospect in usa or...
# 1306119                              is foam insul toxic ?
# 1306120  how can one start a research project base on b...
# 1306121  who win in a battl between a wolverin and a pu...
#
# [1306122 rows x 6 columns]

# %%
errors = np.array([test_text, target_test, preds])
errors_df = pd.DataFrame(errors.transpose(), columns = ['text', 'label', 'preds'])

# %%
errors_analysis_df = errors_df[errors_df["label"] != errors_df["preds"]]

# %%
pd.set_option('display.max_colwidth', None)
errors_analysis_df.sample(50)
# Out:
#                                                                                                                                                                                        text  \
# 21713             whi do some peopl place so much valu on athlet competit ? for instanc neither my mom nor my dad turn off sport tv until bedtim it as if life revolv around these competit
# 16936                                                                                                           can an atheist tell me how badli charl darwin is suffer in hell right now ?
# 2868                                                                                                                                                               are mexican emot peopl ?
# 29959  what can societi do to circumv or at least mitig the impend financi crisi ? have we not learn enough from the 2008 crisi to prevent similar event in the present or nearterm futur ?
# 5272                                                                                                   the quora moder ha declar war against you and all your follow ! how do you proceed ?
# 5755                                                                                                                                                  what are the best custom weed label ?
# 31370                                                  whi tataski ha onli block doordarshan while cricket match broadcast ? now in india do we need to pay for watch doordarshan as well ?
# 29921                                                                                                                  my daughter refus to let me kiss her on the cheek what should i do ?
# 14884                                                                       whi do doctor alway lie about the actual level of pain and side effect involv in mani medic test and procedur ?
# 25712                                                                                                                      is everyon in the seattl area drive over the speed limit of 60 ?
# 7941                                                                                      what do you think about emili parker from the sandi hook newtown shoot where she supposedli die ?
# 24214                                                                           how would gun control advoc respond if gun owner start form local militia that provid train and disciplin ?
# 16504                                                                                                                                             do nh mental health staff prey on peopl ?
# 13650                                                                                                                                 do famili orgi realli happen ? ha anyon been in one ?
# 24560                                                              how do i delet my quora account ? i never even tri to creat one to begin with and now im get email about peopl follow me
# 27266                                                                                                                                           whi is a blastoma more common in children ?
# 3405                                                                                                                where should i buri my dead neighbour dick as i wish to sell it later ?
# 16434                                                                                                              what could be the reason that 98 of rape case in india are incest rape ?
# 13030                                                                                                                 is it true that employ in america wont hire you if you have bad acn ?
# 31812                                                                                                                           can children see what adult cant see ? is it true or fals ?
# 39281                                                                                                                      whi are student from privat engin colleg in india consid loser ?
# 28930                                                          whi do some peopl who are old and have more than enough money to continu the same standard of live do not consid get retir ?
# 10208                                                                                                                    what can be done to educ british peopl of their true coloni past ?
# 1124                                                                      can a countri that fix it exchang rate rel to the dollar lower domest nomin interest rate below us rate ? explain
# 14129                                                                 what made laurent blanc think that he wa veri qualifi to be the manag of the franc nation footbal team back in 2010 ?
# 38808                                                                                                                                                             is donold trump a faget ?
# 20454                                                                                                    what is a reason number of kill or sexual partner for a 1617yearold girl to have ?
# 35326                                                                                                                                                      is marilyn manson a real demon ?
# 40080                                              if you are award a default judgment in a civil case in the us and the parti at fault refus to pay how do you go about collect the fund ?
# 37148                                                                                   doe hollywood whitewash a lot of their film mainli becaus they think minor actor wont sell ticket ?
# 15584                                                                                                                                                  how can liber regain conserv trust ?
# 2556                                                                                                                                 whi doe the ira make such a fuss about north ireland ?
# 33909                                                                                                                                      how doe it feel to penetr the vagina of a hors ?
# 38295                                                                                                     how would fat accept folk feel if their bodi fat wa use as an altern fuel sourc ?
# 2804                                                                                                                                                          should indian stop reproduc ?
# 23268                                                                                          whi is our lord shiva trap insid the kaaba ? what are the muslim get by trap our shiv ling ?
# 1344                                                                                                                        what would happen if half of the indian popul suddenli vanish ?
# 1864                                                              if republican which have all branch of govern dont ban abort should they be critic when they bring the issu up in elect ?
# 20514                                                    im from india i believ im veri talent and would love to be a footbal player in england which english club conduct trial in india ?
# 37438                  whi i cant see best friend in ani of my friend ? is it my fault ? i dont feel like i have a closebest friend till now i want to overcom that feel what should i do ?
# 19720                                                                                                                    how badli did the british screw up india pakistan and bangladesh ?
# 3234                                                                                                                                            should we consid problack leader as fraud ?
# 10238                                                                                                                     whi do women fail to distinguish between kind guy and cruel guy ?
# 7422                                                                                                                               whi is not god krishna protect india from islamophobia ?
# 8572                                                                                                                                       how doe a mother becom pregnant by her own son ?
# 25353                                                                                                                                 whi is there no legisl protect men from gold digger ?
# 7090                                                                                                                                                      should jj abram quit ruin thing ?
# 32278                                                                                                                                                        how is my cock in my profiel ?
# 29493                                                                                                                                                how do i wipe my ass with sand paper ?
# 9123                                                                                                                               what can i do to get rid of asian and black from quora ?
#
#       label preds
# 21713     0     1
# 16936     1     0
# 2868      1     0
# 29959     0     1
# 5272      1     0
# 5755      1     0
# 31370     0     1
# 29921     1     0
# 14884     0     1
# 25712     1     0
# 7941      1     0
# 24214     0     1
# 16504     1     0
# 13650     1     0
# 24560     0     1
# 27266     0     1
# 3405      1     0
# 16434     1     0
# 13030     0     1
# 31812     0     1
# 39281     1     0
# 28930     0     1
# 10208     0     1
# 1124      0     1
# 14129     0     1
# 38808     1     0
# 20454     1     0
# 35326     1     0
# 40080     0     1
# 37148     0     1
# 15584     1     0
# 2556      0     1
# 33909     1     0
# 38295     1     0
# 2804      1     0
# 23268     1     0
# 1344      1     0
# 1864      0     1
# 20514     0     1
# 37438     0     1
# 19720     0     1
# 3234      1     0
# 10238     0     1
# 7422      0     1
# 8572      1     0
# 25353     0     1
# 7090      1     0
# 32278     1     0
# 29493     1     0
# 9123      1     0

# %%
pd.set_option('display.max_colwidth', None)
errors_df[errors_df["label"] == errors_df["preds"]].sample(40)
# Out:
#                                                                                                                                                                                                       text  \
# 11611                                                                                                                           whi do american liber are so attach to free educ when it a veri bad idea ?
# 28011                                                                                                                        should indian invad pakistan bangladesh and nepal becaus we are so superpow ?
# 35618                                                           whi is islam a violent religion ? whi all terrorist are all from islam onli ? whi isnt islam peac like buddhism hinduism jainism sikhism ?
# 8112                                                                                                                                 what would you do if you found out that one of your parent is cheat ?
# 31373                                                                                                                          what are some of the interest fact about shahrukh khan next movi the ring ?
# 20569                                                                                                             how can an american citizen help presid trump make the mexican govern pay for the wall ?
# 9421                                                                                                                                                          how can you compar the sun with other star ?
# 35118                                                                                        what is the earliest point in a game of kerbal space program where you are abl to get a spacecraft to eeloo ?
# 27907                                                                           what kind of question can one encount in a written interview for a broadcast journalist job with an intern media organis ?
# 21160                                                                                                                                                      what are the area where we use graphic design ?
# 30056                                                                                       if you want to train martial art explicitli for self defens how do you find a good school and avoid a mcdojo ?
# 30370                                                                                                                                                                     whi are black men such betamal ?
# 23562                                                                                                                       whi are the indian men so proud of their mustach think they are hot when not ?
# 23580                                                                                                                                           will batu be the best univers in maharashtra after 3year ?
# 7256                 if there is an endless suppli of men especi onlin and there are beta men that dont mind accept even unattract or obes women how come some women end up involuntarili singl for life ?
# 6607                                                                                       doe the newest gener of democrat want to chang our form of govern from a democrat republ to a socialist regim ?
# 29973                                                                                                                                                             whi are men mental stronger than women ?
# 19267                                                                             is thi the right time to invest in mutual fund when gst is go to be implement ? if ye which one is best for monthli 5k ?
# 19931                                           whi do liber hate america and their fellow american ? all i ever hear is critic of just about everyth about my countri you dont have to live here you know
# 16501                                                                                                                               what method doe parapsycholog employ for investig paranorm phenomena ?
# 30773                                                                                                                          what is the best way to synchronis dynamodb with local databas on android ?
# 31970                                                                                                                                                                          what doe esthiolog entail ?
# 14878                                                                                                                    whi would democrat shut down the govern to help illeg alien while hurt american ?
# 12916                                                                                                                                              what are philosophi of chines govern and chines peopl ?
# 16929                                                                                                                                      is there a recip for chiffon cake for those on a ketogen diet ?
# 11821                                                                      what is the best way to convinc the isra that they have to end occupi palestin and respect the right of the palestinian peopl ?
# 15247                                                                                                         what print servic are good that connect to wix websit print differ type of paper and deliv ?
# 20290                                                                                                                                             doe everyon with the same birthday have the same chart ?
# 19405                                                                                                                                                                         what the religion of japan ?
# 15725                                                                                                                                        whi doe the world decri white racism but ignor black racism ?
# 27037                                                                 whi do so mani girl now think it look good to have these stupid avatar morph pic with bunni ear and big eye as their profil pictur ?
# 17106  i ask mani conserv polit question i just receiv a messag from quora say that these question violat your insincer polici my question therefor is doe quora onli accept sincer liber theme question ?
# 39236                                                                                                                                                   whi do male anim get close sexual to human femal ?
# 3345                                                                                                                        whi do white and arab continu to lie about ancient egyptian be black african ?
# 23239                                                                                                                                                 what if u feel like it but u dont love them anymor ?
# 5396                                                                                                                                                        is it necessari to regist a marriag in india ?
# 37360                                                                                                                                                               who is the architect of nid bangalor ?
# 8413                                                                                                                                         do you find quiet and introvert black women weird or strang ?
# 14194                                                              what would be it surfac temperatur ? if a tungsten wire of 2 mm diamet and 1 m length is connect with a electr sourc and produc 20 watt
# 11463                                                                                                                                                      whi is the indian race superior to the chines ?
#
#       label preds
# 11611     1     1
# 28011     1     1
# 35618     1     1
# 8112      0     0
# 31373     0     0
# 20569     1     1
# 9421      0     0
# 35118     0     0
# 27907     0     0
# 21160     0     0
# 30056     0     0
# 30370     1     1
# 23562     1     1
# 23580     0     0
# 7256      1     1
# 6607      1     1
# 29973     1     1
# 19267     0     0
# 19931     1     1
# 16501     0     0
# 30773     0     0
# 31970     0     0
# 14878     1     1
# 12916     0     0
# 16929     0     0
# 11821     1     1
# 15247     0     0
# 20290     0     0
# 19405     0     0
# 15725     1     1
# 27037     1     1
# 17106     1     1
# 39236     1     1
# 3345      1     1
# 23239     0     0
# 5396      0     0
# 37360     0     0
# 8413      1     1
# 14194     0     0
# 11463     1     1

# %% [markdown]
# Custom Word2Vec + Random Forest Model

# %% [markdown]
# Create Vectors from Quora Dataset

# %% [markdown]
# Random Forest

# %% [markdown]
# Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

param_grid = { 
    'n_estimators': [200],
    'max_features': ['auto', 'sqrt', 'log2']
}

CV_rfc = GridSearchCV(estimator=clf, param_grid=param_grid, cv= 5)
CV_rfc.fit(train_tfidf, target_train)

print(CV_rfc.best_params_)

# %% [markdown]
# Error analysis

# %%
test_tfidf convert back into regular vectors and see what samples they were 
stemmed and tokenized 
and regular 

then compare the difference
